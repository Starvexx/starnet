# %%
import tensorflow as tf
from PIL import Image as img
import logging
tf.get_logger().setLevel(logging.ERROR)
from starnet_v1_TF2 import StarNet
# Out:
# 2022-09-14 11:40:00.765334: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-14 11:40:00.948791: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
tf.version.VERSION
# Out:
# '2.10.0'

# %%
starnet = StarNet(mode = 'RGB', window_size = 512, train_folder = './train/', lr = 1e-4)

# %%
starnet.load_training_dataset()
# Out:
# Total training images found: 1
# Total size of training images: 8.33 MP
# One epoch is set to 31 iterations
# Training dataset has been successfully loaded!

# %%
starnet.load_model('./weights', './history')
# Out:
# 2022-09-14 11:40:20.639965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:20.679927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:20.680113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:20.680825: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-14 11:40:20.681647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:20.681825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:20.681967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:21.461784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:21.461979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:21.462148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-14 11:40:21.462307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1508 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 3GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-09-14 11:40:21.462805: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
starnet.train(1, plot_progress = True, plot_interval = 500)
# Out:
# 2022-09-14 11:41:07.591724: E tensorflow/stream_executor/cuda/cuda_dnn.cc:389] Could not create cudnn handle: CUDNN_STATUS_NOT_INITIALIZED
# 2022-09-14 11:41:07.591830: E tensorflow/stream_executor/cuda/cuda_dnn.cc:398] Possibly insufficient driver version: 515.65.1
# 2022-09-14 11:41:07.591880: W tensorflow/core/framework/op_kernel.cc:1780] OP_REQUIRES failed at conv_ops.cc:1134 : UNIMPLEMENTED: DNN library is not found.
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 starnet.train(1, plot_progress = True, plot_interval = 500)
#
# File ~/src_builds/starnet_fits_support/starnet_v1_TF2.py:199, in StarNet.train(self, epochs, augmentation, plot_progress, plot_interval, save_backups, warm_up)
#     197 ax[0].imshow((x[0] + 1) / 2)
#     198 ax[0].set_title('Original')
# --> 199 ax[1].imshow((self.G(x)[0] + 1) / 2)
#     200 ax[1].set_title('Starless')
#     201 ax[2].imshow((y[0] + 1) / 2)
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:7209, in raise_from_not_ok_status(e, name)
#    7207 def raise_from_not_ok_status(e, name):
#    7208   e.message += (" name: " + name if name is not None else "")
# -> 7209   raise core._status_to_exception(e) from None
#
# UnimplementedError: Exception encountered when calling layer "conv2d" "                 f"(type Conv2D).
#
# {{function_node __wrapped__Conv2D_device_/job:localhost/replica:0/task:0/device:GPU:0}} DNN library is not found. [Op:Conv2D]
#
# Call arguments received by layer "conv2d" "                 f"(type Conv2D):
#   • inputs=tf.Tensor(shape=(1, 512, 512, 3), dtype=float32)

# %%
starnet.save_model('./weights', './history')

# %%
starnet.plot_history(last = 100000)

# %% [markdown]
# <h4>Image transformation example. Works with 8bit and 16bit TIFF files</h4>

# %%
in_name = "rgb_test5_16.tif"
out_name = "rgb_test5_16_starless.tif"
starnet.transform(in_name, out_name)
